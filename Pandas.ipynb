# %%
import pandas as pd

# %%
df_dict = {'player_id': {0: 401, 1: 401, 2:  401, 3: 401, 4: 401, 5: 401, 6: 401, 7: 401, 8: 401, 9: 401, 10: 402, 11: 402, 12: 402, 13: 402, 14: 402, 15: 402, 16: 402, 17: 402, 18: 402, 19: 402, 20: 403, 21: 403, 22: 403, 23: 403, 24: 403, 25: 403, 26: 403, 27: 403, 28: 403, 29: 403, 30: 404, 31: 404, 32: 404, 33: 404, 34: 404, 35: 404, 36: 404, 37: 404, 38: 404, 39: 405, 40: 405, 41: 405, 42: 405, 43: 405, 44: 405, 45: 405, 46: 405, 47: 405, 48: 405}, 'match_date': {0: '2021-05-04 00:00:00', 1: '2021-05-09 00:00:00', 2: '2021-05-16 00:00:00', 3: '2021-05-18 00:00:00', 4: '2021-05-22 00:00:00', 5: '2021-06-15 00:00:00', 6: '2021-06-16 00:00:00', 7: '2021-06-18 00:00:00', 8: '2021-07-06 00:00:00', 9: '2021-07-13 00:00:00', 10: '2021-05-14 00:00:00', 11: '2021-05-23 00:00:00', 12: '2021-05-24 00:00:00', 13: '2021-06-01 00:00:00', 14: '2021-06-02 00:00:00', 15: '2021-07-01 00:00:00', 16: '2021-07-11 00:00:00', 17: '2021-07-20 00:00:00', 18: '2021-07-26 00:00:00', 19: '2021-07-30 00:00:00', 20: '2021-05-03 00:00:00', 21: '2021-05-11 00:00:00', 22: '2021-05-12 00:00:00', 23: '2021-05-13 00:00:00', 24: '2021-05-20 00:00:00', 25: '2021-05-25 00:00:00', 26: '2021-07-06 00:00:00', 27: '2021-07-15 00:00:00', 28: '2021-07-22 00:00:00', 29: '2021-07-23 00:00:00', 30: '2021-05-10 00:00:00', 31: '2021-05-16 00:00:00', 32: '2021-05-20 00:00:00', 33: '2021-05-22 00:00:00', 34: '2021-05-28 00:00:00', 35: '2021-06-06 00:00:00', 36: '2021-06-14 00:00:00', 37: '2021-07-25 00:00:00', 38: '2021-07-26 00:00:00', 39: '2021-05-07 00:00:00', 40: '2021-05-25 00:00:00', 41: '2021-06-06 00:00:00', 42: '2021-06-07 00:00:00', 43: '2021-06-14 00:00:00', 44: '2021-07-01 00:00:00', 45: '2021-07-02 00:00:00', 46: '2021-07-14 00:00:00', 47: '2021-07-16 00:00:00', 48: '2021-07-30 00:00:00'}, 'match_result': {0: 'W', 1: 'L', 2: 'L', 3: 'W', 4: 'L', 5: 'L', 6: 'W', 7: 'W', 8: 'L', 9: 'L', 10: 'L', 11: 'L', 12: 'W', 13: 'W', 14: 'W', 15: 'W', 16: 'W', 17: 'L', 18: 'L', 19: 'L', 20: 'L', 21: 'W', 22: 'W', 23: 'W', 24: 'W', 25: 'W', 26: 'L', 27: 'L', 28: 'W', 29: 'W', 30: 'W', 31: 'W', 32: 'W', 33: 'W', 34: 'L', 35: 'L', 36: 'W', 37: 'W', 38: 'L', 39: 'L', 40: 'L', 41: 'L', 42: 'L', 43: 'L', 44: 'L', 45: 'L', 46: 'W', 47: 'L', 48: 'L'}}

# %%
df =pd.DataFrame(df_dict)

# %%
df.sort_values(by='match_date',inplace=True)

# %%
df_403 = df[df['player_id']==403]

# %%
df_403
# Out:
#     player_id           match_date match_result
# 20        403  2021-05-03 00:00:00            L
# 21        403  2021-05-11 00:00:00            W
# 22        403  2021-05-12 00:00:00            W
# 23        403  2021-05-13 00:00:00            W
# 24        403  2021-05-20 00:00:00            W
# 25        403  2021-05-25 00:00:00            W
# 26        403  2021-07-06 00:00:00            L
# 27        403  2021-07-15 00:00:00            L
# 28        403  2021-07-22 00:00:00            W
# 29        403  2021-07-23 00:00:00            W

# %%
df_403['match_result_shifted']  = df_403['match_result'].shift()
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_3844\2809121214.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_403['match_result_shifted']  = df_403['match_result'].shift()

# %%
df_403['streak_start'] = df_403['match_result']!=df_403['match_result_shifted']
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_3844\406052356.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_403['streak_start'] = df_403['match_result']!=df_403['match_result_shifted']

# %%
df_403
# Out:
#     player_id           match_date match_result match_result_shifted  \
# 20        403  2021-05-03 00:00:00            L                  NaN
# 21        403  2021-05-11 00:00:00            W                    L
# 22        403  2021-05-12 00:00:00            W                    W
# 23        403  2021-05-13 00:00:00            W                    W
# 24        403  2021-05-20 00:00:00            W                    W
# 25        403  2021-05-25 00:00:00            W                    W
# 26        403  2021-07-06 00:00:00            L                    W
# 27        403  2021-07-15 00:00:00            L                    L
# 28        403  2021-07-22 00:00:00            W                    L
# 29        403  2021-07-23 00:00:00            W                    W
#
#     streak_start
# 20          True
# 21          True
# 22         False
# 23         False
# 24         False
# 25         False
# 26          True
# 27         False
# 28          True
# 29         False

# %%
df_403['streak_id'] = df_403['streak_start'].cumsum()
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_3844\1051761023.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_403['streak_id'] = df_403['streak_start'].cumsum()

# %%
df_403['streak_count'] = df_403.groupby('streak_id').cumcount()+1
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_3844\2975899998.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_403['streak_count'] = df_403.groupby('streak_id').cumcount()+1

# %%
df_403
# Out:
#     player_id           match_date match_result match_result_shifted  \
# 20        403  2021-05-03 00:00:00            L                  NaN
# 21        403  2021-05-11 00:00:00            W                    L
# 22        403  2021-05-12 00:00:00            W                    W
# 23        403  2021-05-13 00:00:00            W                    W
# 24        403  2021-05-20 00:00:00            W                    W
# 25        403  2021-05-25 00:00:00            W                    W
# 26        403  2021-07-06 00:00:00            L                    W
# 27        403  2021-07-15 00:00:00            L                    L
# 28        403  2021-07-22 00:00:00            W                    L
# 29        403  2021-07-23 00:00:00            W                    W
#
#     streak_start  streak_id  streak_count
# 20          True          1             1
# 21          True          2             1
# 22         False          2             2
# ...

# %%
for index,row in df.groupby('player_id'):
    print(index," : ",row.sort_values(by='match_date'))
# Out:
# 401  :     player_id           match_date match_result
# 0        401  2021-05-04 00:00:00            W
# 1        401  2021-05-09 00:00:00            L
# 2        401  2021-05-16 00:00:00            L
# 3        401  2021-05-18 00:00:00            W
# 4        401  2021-05-22 00:00:00            L
# 5        401  2021-06-15 00:00:00            L
# 6        401  2021-06-16 00:00:00            W
# 7        401  2021-06-18 00:00:00            W
# 8        401  2021-07-06 00:00:00            L
# 9        401  2021-07-13 00:00:00            L
# 402  :      player_id           match_date match_result
# 10        402  2021-05-14 00:00:00            L
# 11        402  2021-05-23 00:00:00            L
# 12        402  2021-05-24 00:00:00            W
# 13        402  2021-06-01 00:00:00            W
# 14        402  2021-06-02 00:00:00            W
# 15        402  2021-07-01 00:00:00            W
# 16        402  2021-07-11 00:00:00            W
# ...
